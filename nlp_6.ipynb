# %% [markdown]
# Word sense disambiguation: Implement a Word Sense Disambiguation (WSD) model using WordNet
# to determine the correct meaning of a word based on its context in a sentence

# %% [markdown]
# ## Step 1: Import libraries

# %%
import nltk

# %%
from nltk.wsd import lesk

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Step 2: Download required data

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PRANAV\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PRANAV\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def improved_lesk(sentence, word):
    context = set(word_tokenize(sentence.lower()))
    best_sense = None
    max_overlap = 0

    for s in wn.synsets(word, pos=wn.NOUN):
        signature = set(word_tokenize(s.definition().lower()))
        for e in s.examples():
            signature.update(word_tokenize(e.lower()))

        overlap = len(context & signature)

        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = s

    return best_sense

# %% [markdown]
# ## Take input from user

# %%
s1 = input("Enter Sentence 1: ")
s2 = input("Enter Sentence 2: ")
word = input("Enter ambiguous word: ")
# Out:
# Enter Sentence 1:  I went to the bank to deposit money in my account
# Enter Sentence 2:  The river water overflowed the bank after heavy rain
# Enter ambiguous word:  bank

# %% [markdown]
# ## Step 5: Apply Lesk algorithm

# %%
sense1 = improved_lesk(s1, word)
sense2 = improved_lesk(s2, word)

# %% [markdown]
# ## Step 6: Print results

# %%
print("\nSentence 1:", s1)
print("Sense:", sense1)
print("Definition:", sense1.definition())

print("\nSentence 2:", s2)
print("Sense:", sense2)
print("Definition:", sense2.definition())
# Out:
# Sentence 1: I went to the bank to deposit money in my account
# Sense: Synset('depository_financial_institution.n.01')
# Definition: a financial institution that accepts deposits and channels the money into lending activities
#
# Sentence 2: The river water overflowed the bank after heavy rain
# Sense: Synset('bank.n.01')
# Definition: sloping land (especially the slope beside a body of water)
